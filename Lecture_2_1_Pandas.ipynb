# %% [markdown]
# # Lecture 2.1: Pandas and structured datasets

# %%
import pandas as pd

# %% [markdown]
# **Pay attention!**
# <br>Pandas is no longer updated on python 2.7 since January 2019 (instead it is so on python 3)

# %% [markdown]
# ## Pandas dataframe, your new best friend

# %% [markdown]
# In general, you could say that the Pandas DataFrame consists of three main components: the data, the index, and the columns.
#
# Firstly, the DataFrame can contain data that is:
# - a Pandas DataFrame
# - a Pandas Series: a one-dimensional labeled array capable of holding any data type with axis labels or index. An example of a Series object is one column from a DataFrame.
# - a NumPy ndarray, which can be a record or structured
#
# Structured arrays allow users to manipulate the data by named fields.
#
# Record arrays, on the other hand, expand the properties of structured arrays. They allow users to access fields of structured arrays by attribute rather than by index.

# %% [markdown]
# ### Your first dataframe

# %%
data = np.array([['','Col0','Col1'],
                ['Row0',0,1],
                ['Row1',2,3]])

# %%
cacca=pd.DataFrame(data=data[1:,1:],
                  index=data[1:,0],
                  columns=data[0,1:])

# %%
cacca
# Out:
#      Col0 Col1
# Row0    0    1
# Row1    2    3

# %% [markdown]
# **Indeces**

# %%
cacca.index
# Out:
# Index([u'Row0', u'Row1'], dtype='object')

# %% [markdown]
# **Columns**

# %%
cacca.columns
# Out:
# Index([u'Col0', u'Col1'], dtype='object')

# %% [markdown]
# Navigate in the DataFrame by **rows**: ***loc*** and ***iloc***.

# %%
cacca.loc['Row0']
# Out:
# Col0    0
# Col1    1
# Name: Row0, dtype: object

# %% [markdown]
# ***loc*** works on the index name

# %%
cacca.iloc[0]
# Out:
# Col0    0
# Col1    1
# Name: Row0, dtype: object

# %% [markdown]
# ***iloc*** works on the position

# %% [markdown]
# Navigate in the DataFrame by **columns** is much easier

# %%
cacca['Col0']
# Out:
# Row0    0
# Row1    2
# Name: Col0, dtype: object

# %%
cacca.Col0
# Out:
# Row0    0
# Row1    2
# Name: Col0, dtype: object

# %% [markdown]
# #### Modify the DataFrame

# %% [markdown]
# Add a **column**

# %%
cacca['Col2']=[2, 4]

# %%
cacca
# Out:
#      Col0 Col1  Col2
# Row0    0    1     2
# Row1    2    3     4

# %% [markdown]
# Add a **row**

# %%
cacca_2=pd.DataFrame(data=[[4,5,6]],
                  index=['Row2'],
                  columns=['Col0','Col1','Col2'])

# %%
cacca.append(cacca_2)
# Out:
#      Col0 Col1  Col2
# Row0    0    1     2
# Row1    2    3     4
# Row2    4    5     6

# %%
cacca
# Out:
#      Col0 Col1  Col2
# Row0    0    1     2
# Row1    2    3     4

# %% [markdown]
# It creates a copy

# %%
cacca=cacca.append(cacca_2)

# %%
cacca
# Out:
#      Col0 Col1  Col2
# Row0    0    1     2
# Row1    2    3     4
# Row2    4    5     6

# %% [markdown]
# Delete a **column**

# %%
del cacca['Col2']

# %%
cacca
# Out:
#      Col0 Col1
# Row0    0    1
# Row1    2    3
# Row2    4    5

# %% [markdown]
# Delete a **row**

# %%
cacca.drop(cacca.index[0])
# Out:
#      Col0 Col1
# Row1    2    3
# Row2    4    5

# %%
cacca
# Out:
#      Col0 Col1
# Row0    0    1
# Row1    2    3
# Row2    4    5

# %% [markdown]
# D'oh! drop returns a copy! In order to modify the original DataFrame, activate the option 'inplace'

# %%
cacca.drop(cacca.index[0], inplace=True)

# %%
cacca
# Out:
#      Col0 Col1
# Row1    2    3
# Row2    4    5

# %% [markdown]
# ### Reading a csv file

# %%
imdb_votes=pd.read_csv('./data/imdb_2018_films_urls.txt', sep='\t')

# %% [markdown]
# ***sep*** is quite straightforward. There are other interesting options, as:
# - ***header*** is which is the column to be used as description of the  column. Since we have none, we set it to none;
# - ***names*** is the name of the columns.
#
# Since someone already fixed the structure of the file, for the moment you do not have to bother about column names or the header.

# %%
imdb_votes
# Out:
#                                            title  \
# 0                         Avengers: Infinity War
# 1                                  Black Panther
# 2                                     Deadpool 2
# 3                               Ready Player One
# 4                                  A Quiet Place
# 5                  Mission: Impossible - Fallout
# 6                                          Venom
# 7                                   Annihilation
# 8                 Jurassic World: Fallen Kingdom
# 9                        Solo: A Star Wars Story
# 10                          Ant-Man and the Wasp
# 11                             Bohemian Rhapsody
# 12                                 Incredibles 2
# 13                                   Tomb Raider
# 14                                    Game Night
# 15                                A Star Is Born
# 16                                   Red Sparrow
# 17                                    Hereditary
# 18                                 Ocean's Eight
# 19   Fantastic Beasts: The Crimes of Grindelwald
# 20                                       Аквамен
# 21                                      Bird Box
# 22                                       Rampage
# 23                                       The Meg
# 24                                  Isle of Dogs
# 25                   Maze Runner: The Death Cure
# 26                         Pacific Rim: Uprising
# 27                                       Апгрейд
# 28                       The Cloverfield Paradox
# 29                   Sicario: Day of the Soldado
# ..                                           ...
# 170                                       Mid90s
# 171                           The Wild Pear Tree
# 172                                        Gotti
# 173                        The Old Man & the Gun
# 174                                Juliet, Naked
# 175                                   Uncle Drew
# 176                                       Dogman
# 177                              Fahrenheit 11/9
# 178                                     Wildling
# 179                           Father of the Year
# 180                                      Siberia
# 181                                 Private Life
# 182                                         Vice
# 183                              Sherlock Gnomes
# 184                              Active Measures
# 185                                Beautiful Boy
# 186                                       Climax
# 187                                     The Mule
# 188                             Acts of Violence
# 189                          Corredor Assombrado
# 190                                          Kin
# 191                        Billionaire Boys Club
# 192                               Instant Family
# 193                      They Shall Not Grow Old
# 194              Goosebumps 2: Haunted Halloween
# 195                                   Proud Mary
# 196                                 Spinning Man
# 197                            Death of a Nation
# 198                               Utøya: July 22
# 199                                      Colette
#
#                                                    url  rating  metascore  \
# 0    https://www.imdb.com//title/tt4154756/?ref_=ad...     8.5         68
# 1    https://www.imdb.com//title/tt1825683/?ref_=ad...     7.4         88
# 2    https://www.imdb.com//title/tt5463162/?ref_=ad...     7.8         66
# 3    https://www.imdb.com//title/tt1677720/?ref_=ad...     7.5         64
# 183  https://www.imdb.com//title/tt2296777/?ref_=ad...     5.1         36
# 184  https://www.imdb.com//title/tt8135494/?ref_=ad...     8.4         68
# 185  https://www.imdb.com//title/tt1226837/?ref_=ad...     7.3         63
# 186  https://www.imdb.com//title/tt8359848/?ref_=ad...     7.7         83
# 187  https://www.imdb.com//title/tt7959026/?ref_=ad...     7.2         58
# 188  https://www.imdb.com//title/tt6684714/?ref_=ad...     5.2         28
# 189  https://www.imdb.com//title/tt2372251/?ref_=ad...     5.2         56
# 190  https://www.imdb.com//title/tt6017942/?ref_=ad...     5.7         35
# 191  https://www.imdb.com//title/tt5179598/?ref_=ad...     5.6         30
# 192  https://www.imdb.com//title/tt7401588/?ref_=ad...     7.6         57
# 193  https://www.imdb.com//title/tt7905466/?ref_=ad...     8.6         92
# 194  https://www.imdb.com//title/tt5664636/?ref_=ad...     5.7         53
# 195  https://www.imdb.com//title/tt6421110/?ref_=ad...     4.9         35
# 196  https://www.imdb.com//title/tt5616294/?ref_=ad...     5.6         44
# 197  https://www.imdb.com//title/tt8564902/?ref_=ad...     4.7          1
# 198  https://www.imdb.com//title/tt7959216/?ref_=ad...     7.5         75
# 199  https://www.imdb.com//title/tt5437928/?ref_=ad...     6.8         74
#
#       votes  runtime
# 0    556607      149
# 1    435846      134
# 2    327083      119
# 3    259630      140
# 4    249406       90
# 5    198276      147
# 6    197816      112
# 7    194795      115
# 8    187521      128
# 9    187191      135
# 10   175967      118
# 11   169065      134
# 12   159121      118
# 13   147098      119
# 14   138645      100
# 15   125848      136
# 16   119504      140
# 17   117376      127
# 18   115541      110
# 19   101976      134
# 20   101289      143
# 21   100102      124
# 22    99624      107
# 23    88725      113
# 24    87168      101
# 25    81807      143
# 26    80292      111
# 27    77662      100
# 28    76384      102
# 29    76122      122
# ..      ...      ...
# 170    7764       85
# 171    7710      188
# 172    7710      112
# 173    7559       93
# 174    7345       97
# 175    7218      103
# 176    7077      103
# 177    7021      128
# 178    6947       92
# 179    6839       94
# 180    6819      104
# 181    6805      123
# 182    6679      132
# 183    6607       86
# 184    6590      109
# 185    6473      120
# 186    6408       95
# 187    6403      116
# 188    6391       86
# 189    6384       96
# 190    6324      102
# 191    6294      108
# 192    6166      118
# 193    6088       99
# 194    5975       90
# 195    5850       89
# 196    5840      100
# 197    5386      108
# 198    5372       93
# 199    5338      111
#
# [200 rows x 6 columns]

# %% [markdown]
# The cool thing is that you can do searches and selection in a fast and clever way

# %%
imdb_votes['title']=='Avengers: Infinity War'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 170    False
# 171    False
# 172    False
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Name: title, Length: 200, dtype: bool

# %% [markdown]
# BTW, here is what is the [Metascore](https://www.metacritic.com/about-metascores) of IMDb.

# %% [markdown]
# Everything works as always...

# %%
mask=imdb_votes['title']=='Avengers: Infinity War'
imdb_votes[mask]
# Out:
#                     title                                                url  \
# 0  Avengers: Infinity War  https://www.imdb.com//title/tt4154756/?ref_=ad...
#
#    rating  metascore   votes  runtime
# 0     8.5         68  556607      149

# %% [markdown]
# Boolean searches

# %%
mask_rating=imdb_votes['rating']==min(imdb_votes['rating'])
imdb_votes[mask_rating]
# Out:
#            title                                                url  rating  \
# 116  Slender Man  https://www.imdb.com//title/tt5690360/?ref_=ad...     3.2
#
#      metascore  votes  runtime
# 116         30  14969       93

# %%
mask_metascore=imdb_votes.metascore<60
imdb_votes[mask_metascore]
# Out:
#                                            title  \
# 6                                          Venom
# 8                 Jurassic World: Fallen Kingdom
# 11                             Bohemian Rhapsody
# 13                                   Tomb Raider
# 16                                   Red Sparrow
# 19   Fantastic Beasts: The Crimes of Grindelwald
# 20                                       Аквамен
# 21                                      Bird Box
# 22                                       Rampage
# 23                                       The Meg
# 25                   Maze Runner: The Death Cure
# 26                         Pacific Rim: Uprising
# 28                       The Cloverfield Paradox
# 31                               The Equalizer 2
# 32                                  The Commuter
# 33                                  The Predator
# 34                                       The Nun
# 37                                    Skyscraper
# 38                                           Tag
# 42                                Den of Thieves
# 49                                     12 Strong
# 51                                    Death Wish
# 52                            Fifty Shades Freed
# 53                       Insidious: The Last Key
# 56                         The Spy Who Dumped Me
# 57                                       Mile 22
# 58                                   Outlaw King
# 59                               The First Purge
# 60         Hotel Transylvania 3: Summer Vacation
# 61                                    Extinction
# ..                                           ...
# 144                                     Dumplin'
# 146                                    Every Day
# 149                           I Can Only Imagine
# 151                         Unfriended: Dark Web
# 153           The Nutcracker and the Four Realms
# 154                  A Futile and Stupid Gesture
# 156                 The Girl in the Spider's Web
# 158                                   Occupation
# 161                            7 Days in Entebbe
# 162                                  In Darkness
# 166                                  Breaking In
# 167                              Forever My Girl
# 168                               White Boy Rick
# 169                        Under the Silver Lake
# 172                                        Gotti
# 175                                   Uncle Drew
# 178                                     Wildling
# 179                           Father of the Year
# 180                                      Siberia
# 183                              Sherlock Gnomes
# 187                                     The Mule
# 188                             Acts of Violence
# 189                          Corredor Assombrado
# 190                                          Kin
# 191                        Billionaire Boys Club
# 192                               Instant Family
# 194              Goosebumps 2: Haunted Halloween
# 195                                   Proud Mary
# 196                                 Spinning Man
# 197                            Death of a Nation
#
#                                                    url  rating  metascore  \
# 6    https://www.imdb.com//title/tt1270797/?ref_=ad...     6.8         35
# 8    https://www.imdb.com//title/tt4881806/?ref_=ad...     6.2         51
# 11   https://www.imdb.com//title/tt1727824/?ref_=ad...     8.3         49
# 13   https://www.imdb.com//title/tt1365519/?ref_=ad...     6.3         48
# 168  https://www.imdb.com//title/tt4537896/?ref_=ad...     6.5         59
# 169  https://www.imdb.com//title/tt5691670/?ref_=ad...     6.4         59
# 172  https://www.imdb.com//title/tt1801552/?ref_=ad...     4.9         24
# 175  https://www.imdb.com//title/tt7334528/?ref_=ad...     5.7         57
# 178  https://www.imdb.com//title/tt5085924/?ref_=ad...     5.5         58
# 179  https://www.imdb.com//title/tt7256866/?ref_=ad...     5.2         32
# 180  https://www.imdb.com//title/tt6494418/?ref_=ad...     4.3         34
# 183  https://www.imdb.com//title/tt2296777/?ref_=ad...     5.1         36
# 187  https://www.imdb.com//title/tt7959026/?ref_=ad...     7.2         58
# 188  https://www.imdb.com//title/tt6684714/?ref_=ad...     5.2         28
# 189  https://www.imdb.com//title/tt2372251/?ref_=ad...     5.2         56
# 190  https://www.imdb.com//title/tt6017942/?ref_=ad...     5.7         35
# 191  https://www.imdb.com//title/tt5179598/?ref_=ad...     5.6         30
# 192  https://www.imdb.com//title/tt7401588/?ref_=ad...     7.6         57
# 194  https://www.imdb.com//title/tt5664636/?ref_=ad...     5.7         53
# 195  https://www.imdb.com//title/tt6421110/?ref_=ad...     4.9         35
# 196  https://www.imdb.com//title/tt5616294/?ref_=ad...     5.6         44
# 197  https://www.imdb.com//title/tt8564902/?ref_=ad...     4.7          1
#
#       votes  runtime
# 6    197816      112
# 8    187521      128
# 11   169065      134
# 13   147098      119
# 16   119504      140
# 19   101976      134
# 20   101289      143
# 21   100102      124
# 22    99624      107
# 23    88725      113
# 25    81807      143
# 26    80292      111
# 28    76384      102
# 31    73048      121
# 32    72367      105
# 33    72022      107
# 34    71426       96
# 37    65557      102
# 38    64580      100
# 42    60251      140
# 49    43571      130
# 51    42021      107
# 52    39124      105
# 53    37859      103
# 56    36135      117
# 57    35962       94
# 58    35388      121
# 59    33837       98
# 60    32825       97
# 61    32607       95
# ..      ...      ...
# 144   10536      110
# 146   10406       97
# 149    9880      110
# 151    9768       92
# 153    9583       99
# 154    9555      101
# 156    8585      117
# 158    8384      119
# 161    8131      107
# 162    8117      110
# 166    7923       88
# 167    7867      108
# 168    7856      111
# 169    7791      139
# 172    7710      112
# 175    7218      103
# 178    6947       92
# 179    6839       94
# 180    6819      104
# 183    6607       86
# 187    6403      116
# 188    6391       86
# 189    6384       96
# 190    6324      102
# 191    6294      108
# 192    6166      118
# 194    5975       90
# 195    5850       89
# 196    5840      100
# 197    5386      108
#
# [108 rows x 6 columns]

# %% [markdown]
# ### Exercise: select unsufficient rating and unsufficient metascore movies

# %% [markdown]
# ### Exercise: select movie appreciated by critics, but not by IMDb users

# %% [markdown]
# ### Exercise: viceversa

# %% [markdown]
# ### Exercise: calculate the correlation between the metascore and the IMDb rating

# %% [markdown]
# ### Exercise: calculate the correlation between the rating and the movie length

# %% [markdown]
# ### Exercise: find the missing movie

# %% [markdown]
# Hint: It's a documentary, thus there are not 'actors'!
